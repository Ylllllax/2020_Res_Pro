# %% [markdown]
# count rate (cts/s)
#
# 00年：    5.404e+00 +/- 1.383e-02
#
# 06年：    2.364e+01 +/- 1.631e-02
#
# 07年：    1.641e+00 +/- 1.036e-02
#
# 09年（1）：1.620e+00 +/- 4.042e-03
#
# 09年（2）：1.851e+00 +/- 5.213e-03
#
# 16年：    5.751e-01 +/- 2.455e-03

# %%
# XSPEC

import matplotlib.pyplot as plt

year = [2000,2006,2007,2009,2016]
cr = [5.404e+00, 2.364e+01, 1.641e+00, (1.620e+00+1.851e+00)/2,  5.751e-01]

plt.figure(figsize=(10,8))
plt.scatter(year, cr, color="r", linewidth=1)
plt.xlabel("year",fontsize=20)
plt.ylabel("count rate",fontsize=20)
plt.tick_params(labelsize=15)
plt.show()

# %%
# XMM-Newton Science Archive

year2 = [2000,2006,2007,2009,2016]
cr2 = [34.301, 14.349, 2.940, (4.930+7.517)/2, 2.066]


plt.figure(figsize=(10,8))
plt.scatter(year2, cr2, color="r", linewidth=1)
plt.xlabel("year",fontsize=20)
plt.ylabel("count rate",fontsize=20)
plt.tick_params(labelsize=15)
plt.show()

# %%
# 抽取光变曲线

year3 = [2000,2006,2007,2009,2016]
cr3 = [24.60, 26.78, 1.83, (3.44+4.63)/2, 1.40]


plt.figure(figsize=(10,8))
plt.scatter(year3, cr3, color="k", linewidth=3)
plt.xlabel("year",fontsize=20)
plt.ylabel("count rate",fontsize=20)
plt.tick_params(labelsize=15)
plt.show()
